# %%
import pandas as pd
import numpy as np

# %%
test_df = pd.read_csv(r"D:\Thesis - November - B7H3\Dataset\Clustering\90_percent\data\test_data_combined.csv")
train_df = pd.read_csv(r"D:\Thesis - November - B7H3\Dataset\Clustering\90_percent\data\train_data.csv")

# %%
test_cluster = test_df["Cluster_name"].unique()
train_cluster = train_df["Cluster_name"].unique()
if any (x in train_cluster for x in test_cluster):
    print("True")
else:
    print("False")
# Out:
# False
